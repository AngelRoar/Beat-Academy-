# %% [markdown]
# # New Work

# %% [markdown]
# ### Simple Calculation

# %%
2026-28
# Out:
# 1998

# %%
2461+429
# Out:
# 2890

# %% [markdown]
# - Pthon
# - SQL
# - Power BI

# %% [markdown]
# ![93-marc-marquez_ds_4975.gallery_full_top_fullscreen.jpg](attachment:223e133d-25c4-4872-9532-e4076ca5584f.jpg)
