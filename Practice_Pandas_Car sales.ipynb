# %% [markdown]
# Pandas Practice

# %%
import pandas as pd 
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %%
pd.read_csv('./Car_sales.csv')
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data = pd.read_csv('./Car_sales.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
data.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %%
data.describe().T
# Out:
#                      count        mean        std         min         25%  \
# Sales_in_thousands   157.0   52.998076  68.029422    0.110000   14.114000
# __year_resale_value  121.0   18.072975  11.453384    5.160000   11.260000
# Price_in_thousands   155.0   27.390755  14.351653    9.235000   18.017500
# Engine_size          156.0    3.060897   1.044653    1.000000    2.300000
# Horsepower           156.0  185.948718  56.700321   55.000000  149.500000
# Wheelbase            156.0  107.487179   7.641303   92.600000  103.000000
# Width                156.0   71.150000   3.451872   62.600000   68.400000
# Length               156.0  187.343590  13.431754  149.400000  177.575000
# Curb_weight          155.0    3.378026   0.630502    1.895000    2.971000
# Fuel_capacity        156.0   17.951923   3.887921   10.300000   15.800000
# Fuel_efficiency      154.0   23.844156   4.282706   15.000000   21.000000
# Power_perf_factor    155.0   77.043591  25.142664   23.276272   60.407707
#
# ...

# %%
data.head(12)
# Out:
#    Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0         Acura  Integra              16.919               16.360
# 1         Acura       TL              39.384               19.875
# 2         Acura       CL              14.114               18.225
# 3         Acura       RL               8.588               29.725
# 4          Audi       A4              20.397               22.255
# 5          Audi       A6              18.780               23.555
# 6          Audi       A8               1.380               39.000
# 7           BMW     323i              19.747                  NaN
# 8           BMW     328i               9.231               28.675
# 9           BMW     528i              17.527               36.125
# 10        Buick  Century              91.561               12.475
# 11        Buick    Regal              39.350               13.740
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
data.tail(3)
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 154        Volvo   V70              17.531                  NaN    Passenger
# 155        Volvo   C70               3.493                  NaN    Passenger
# 156        Volvo   S80              18.969                  NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 154                28.8          2.4       168.0      104.9   69.3   186.2
# 155                45.5          2.3       236.0      104.9   71.5   185.7
# 156                36.0          2.9       201.0      109.9   72.1   189.8
#
#      Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 154        3.259           17.9             25.0     6/25/2011
# 155        3.601           18.5             23.0     4/26/2011
# 156        3.600           21.1             24.0    11/14/2011
#
#      Power_perf_factor
# 154          71.155978
# 155         101.623357
# 156          85.735655

# %%
data.sample(6)
# Out:
#     Manufacturer   Model  Sales_in_thousands  __year_resale_value  \
# 39         Dodge   Viper               0.916               58.470
# 106       Nissan  Xterra              54.158                  NaN
# 70         Lexus   ES300              24.072               26.975
# 3          Acura      RL               8.588               29.725
# 2          Acura      CL              14.114               18.225
# 9            BMW    528i              17.527               36.125
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 39     Passenger              69.725          8.0       450.0       96.2
# 106          Car              22.799          3.3       170.0      104.3
# 70     Passenger              31.505          3.0       210.0      105.1
# 3      Passenger              42.000          3.5       210.0      114.6
# 2      Passenger                 NaN          3.2       225.0      106.9
# ...

# %%
data.shape
# Out:
# (157, 16)

# %%
data.size
# Out:
# 2512

# %%
data.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
data.Model
# Out:
# 0      Integra
# 1           TL
# 2           CL
# 3           RL
# 4           A4
#         ...
# 152        V40
# 153        S70
# 154        V70
# 155        C70
# 156        S80
# Name: Model, Length: 157, dtype: object

# %%
data.Manufacturer
# Out:
# 0      Acura
# 1      Acura
# 2      Acura
# 3      Acura
# 4       Audi
#        ...
# 152    Volvo
# 153    Volvo
# 154    Volvo
# 155    Volvo
# 156    Volvo
# Name: Manufacturer, Length: 157, dtype: object

# %%
data.Manufacturer.dtype
# Out:
# dtype('O')

# %% [markdown]
# Null count:-

# %%
data.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
data.isnull().mean()*100
# Out:
# Manufacturer            0.000000
# Model                   0.000000
# Sales_in_thousands      0.000000
# __year_resale_value    22.929936
# Vehicle_type            0.000000
# Price_in_thousands      1.273885
# Engine_size             0.636943
# Horsepower              0.636943
# Wheelbase               0.636943
# Width                   0.636943
# Length                  0.636943
# Curb_weight             1.273885
# Fuel_capacity           0.636943
# Fuel_efficiency         1.910828
# Latest_Launch           0.000000
# Power_perf_factor       1.273885
# dtype: float64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.dropna()
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
data.drop(columns="Width")
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data.drop(columns="Width", inplace=True)

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data.reset_index()
# Out:
#      index Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0        0        Acura  Integra              16.919               16.360
# 1        1        Acura       TL              39.384               19.875
# 2        3        Acura       RL               8.588               29.725
# 3        4         Audi       A4              20.397               22.255
# 4        5         Audi       A6              18.780               23.555
# ..     ...          ...      ...                 ...                  ...
# 112    145   Volkswagen     Golf               9.761               11.425
# 113    146   Volkswagen    Jetta              83.721               13.240
# 114    147   Volkswagen   Passat              51.102               16.725
# 115    148   Volkswagen   Cabrio               9.569               16.575
# 116    149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
data.reset_index(drop=True, inplace=True)

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       RL               8.588               29.725
# 3           Audi       A4              20.397               22.255
# 4           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 112   Volkswagen     Golf               9.761               11.425
# 113   Volkswagen    Jetta              83.721               13.240
# 114   Volkswagen   Passat              51.102               16.725
# 115   Volkswagen   Cabrio               9.569               16.575
# 116   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data.loc[7:14]
# Out:
#    Manufacturer        Model  Sales_in_thousands  __year_resale_value  \
# 7           BMW         528i              17.527               36.125
# 8         Buick      Century              91.561               12.475
# 9         Buick        Regal              39.350               13.740
# 10        Buick  Park Avenue              27.851               20.190
# 11        Buick      LeSabre              83.257               13.360
# 12     Cadillac      DeVille              63.729               22.525
# 13     Cadillac     Eldorado               6.536               25.725
# 14     Cadillac       Catera              11.185               18.225
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 7     Passenger              38.900          2.8       193.0      111.4
# 8     Passenger              21.975          3.1       175.0      109.0
# 9     Passenger              25.300          3.8       240.0      109.0
# ...

# %%
data.iloc[7:14]
# Out:
#    Manufacturer        Model  Sales_in_thousands  __year_resale_value  \
# 7           BMW         528i              17.527               36.125
# 8         Buick      Century              91.561               12.475
# 9         Buick        Regal              39.350               13.740
# 10        Buick  Park Avenue              27.851               20.190
# 11        Buick      LeSabre              83.257               13.360
# 12     Cadillac      DeVille              63.729               22.525
# 13     Cadillac     Eldorado               6.536               25.725
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 7     Passenger              38.900          2.8       193.0      111.4
# 8     Passenger              21.975          3.1       175.0      109.0
# 9     Passenger              25.300          3.8       240.0      109.0
# 10    Passenger              31.965          3.8       205.0      113.8
# ...

# %%
data.iloc[:7]
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       RL               8.588               29.725    Passenger
# 3         Audi       A4              20.397               22.255    Passenger
# 4         Audi       A6              18.780               23.555    Passenger
# 5         Audi       A8               1.380               39.000    Passenger
# 6          BMW     328i               9.231               28.675    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Length  \
# 0               21.50          1.8       140.0      101.2   172.4
# 1               28.40          3.2       225.0      108.1   192.9
# 2               42.00          3.5       210.0      114.6   196.6
# 3               23.99          1.8       150.0      102.6   178.0
# ...

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       RL               8.588               29.725
# 3           Audi       A4              20.397               22.255
# 4           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 112   Volkswagen     Golf               9.761               11.425
# 113   Volkswagen    Jetta              83.721               13.240
# 114   Volkswagen   Passat              51.102               16.725
# 115   Volkswagen   Cabrio               9.569               16.575
# 116   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %% [markdown]
# Calling columns

# %%
data.Model
# Out:
# 0      Integra
# 1           TL
# 2           RL
# 3           A4
# 4           A6
#         ...
# 112       Golf
# 113      Jetta
# 114     Passat
# 115     Cabrio
# 116        GTI
# Name: Model, Length: 117, dtype: object

# %%
data['Model']
# Out:
# 0      Integra
# 1           TL
# 2           RL
# 3           A4
# 4           A6
#         ...
# 112       Golf
# 113      Jetta
# 114     Passat
# 115     Cabrio
# 116        GTI
# Name: Model, Length: 117, dtype: object

# %%
data.Engine_size.value_counts()
# Out:
# Engine_size
# 2.0    14
# 3.0    11
# 1.8     8
# 3.8     8
# 4.6     8
# 2.4     8
# 2.5     8
# 4.0     6
# 3.5     5
# 3.4     5
# 3.1     4
# 3.2     3
# 1.9     3
# 3.3     3
# 2.7     3
# 2.8     3
# 3.9     2
# 2.2     2
# 2.3     2
# 4.3     2
# 1.0     1
# 8.0     1
# 5.2     1
# 5.7     1
# 1.6     1
# 1.5     1
# 4.2     1
# 5.0     1
# 4.7     1
# Name: count, dtype: int64

# %%
data.Engine_size.nunique()
# Out:
# 29

# %%
data.Engine_size.unique()
# Out:
# array([1.8, 3.2, 3.5, 2.8, 4.2, 3.1, 3.8, 4.6, 3. , 2.2, 3.4, 5.7, 1. ,
#        2.5, 2.7, 2. , 8. , 5.2, 3.9, 2.4, 4. , 1.6, 2.3, 1.5, 3.3, 4.3,
#        5. , 1.9, 4.7])

# %%
data.Price_in_thousands.sum()
# Out:
# np.float64(3038.43)

# %%
data.Price_in_thousands.min()
# Out:
# 9.235

# %%
data.Price_in_thousands.max()
# Out:
# 82.6

# %%
data.Price_in_thousands.mean()
# Out:
# np.float64(25.969487179487178)

# %% [markdown]
# Sorting

# %%
data.sort_values(by= 'Horsepower')
# Out:
#     Manufacturer          Model  Sales_in_thousands  __year_resale_value  \
# 22     Chevrolet          Metro              21.855                5.160
# 52       Hyundai         Accent              41.184                5.860
# 102       Saturn             SC              24.546               10.590
# 101       Saturn             SL              80.620                9.200
# 47         Honda          Civic             199.685                9.850
# ..           ...            ...                 ...                  ...
# 99       Porsche  Carrera Coupe               1.280               60.625
# 80    Mercedes-B       SL-Class               3.311               58.600
# 5           Audi             A8               1.380               39.000
# 20     Chevrolet       Corvette              17.947               36.225
# 31         Dodge          Viper               0.916               58.470
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
data.sort_values(by= 'Horsepower', ascending= False)
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 31         Dodge           Viper               0.916               58.470
# 20     Chevrolet        Corvette              17.947               36.225
# 5           Audi              A8               1.380               39.000
# 80    Mercedes-B        SL-Class               3.311               58.600
# 100      Porsche  Carrera Cabrio               1.866               67.550
# ..           ...             ...                 ...                  ...
# 47         Honda           Civic             199.685                9.850
# 101       Saturn              SL              80.620                9.200
# 102       Saturn              SC              24.546               10.590
# 52       Hyundai          Accent              41.184                5.860
# 22     Chevrolet           Metro              21.855                5.160
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %% [markdown]
# Filtering

# %%
data[data["Fuel_capacity"]> 20]
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 5           Audi              A8               1.380               39.000
# 32         Dodge      Ram Pickup             227.061               15.060
# 33         Dodge       Ram Wagon              16.767               15.510
# 34         Dodge         Ram Van              31.038               13.425
# 35         Dodge          Dakota             111.313               11.260
# 42          Ford        Explorer             276.747               16.640
# 43          Ford        Windstar             155.787               13.175
# 44          Ford      Expedition             125.338               23.575
# 46          Ford        F-Series             540.561               15.075
# 50         Honda        Passport              12.855               17.525
# 58          Jeep  Grand Cherokee             157.040               18.810
# 61         Lexus           LS400               6.375               40.375
# ...

# %%
data.reset_index()
# Out:
#      index Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0        0        Acura  Integra              16.919               16.360
# 1        1        Acura       TL              39.384               19.875
# 2        2        Acura       RL               8.588               29.725
# 3        3         Audi       A4              20.397               22.255
# 4        4         Audi       A6              18.780               23.555
# ..     ...          ...      ...                 ...                  ...
# 112    112   Volkswagen     Golf               9.761               11.425
# 113    113   Volkswagen    Jetta              83.721               13.240
# 114    114   Volkswagen   Passat              51.102               16.725
# 115    115   Volkswagen   Cabrio               9.569               16.575
# 116    116   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
data_fuel = data[data["Fuel_capacity"]> 20]

# %%
data_fuel.drop(columns='Vehicle_type', inplace=True)

# %%
data_fuel
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 5           Audi              A8               1.380               39.000
# 32         Dodge      Ram Pickup             227.061               15.060
# 33         Dodge       Ram Wagon              16.767               15.510
# 34         Dodge         Ram Van              31.038               13.425
# 35         Dodge          Dakota             111.313               11.260
# 42          Ford        Explorer             276.747               16.640
# 43          Ford        Windstar             155.787               13.175
# 44          Ford      Expedition             125.338               23.575
# 46          Ford        F-Series             540.561               15.075
# 50         Honda        Passport              12.855               17.525
# 58          Jeep  Grand Cherokee             157.040               18.810
# 61         Lexus           LS400               6.375               40.375
# ...

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       RL               8.588               29.725
# 3           Audi       A4              20.397               22.255
# 4           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 112   Volkswagen     Golf               9.761               11.425
# 113   Volkswagen    Jetta              83.721               13.240
# 114   Volkswagen   Passat              51.102               16.725
# 115   Volkswagen   Cabrio               9.569               16.575
# 116   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data_fuel
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 5           Audi              A8               1.380               39.000
# 32         Dodge      Ram Pickup             227.061               15.060
# 33         Dodge       Ram Wagon              16.767               15.510
# 34         Dodge         Ram Van              31.038               13.425
# 35         Dodge          Dakota             111.313               11.260
# 42          Ford        Explorer             276.747               16.640
# 43          Ford        Windstar             155.787               13.175
# 44          Ford      Expedition             125.338               23.575
# 46          Ford        F-Series             540.561               15.075
# 50         Honda        Passport              12.855               17.525
# 58          Jeep  Grand Cherokee             157.040               18.810
# 61         Lexus           LS400               6.375               40.375
# ...

# %%
data_fuel.drop(columns= ['Power_perf_factor','__year_resale_value',  'Sales_in_thousands'], inplace=True)

# %%
data_fuel
# Out:
#     Manufacturer           Model  Price_in_thousands  Engine_size  Horsepower  \
# 5           Audi              A8              62.000          4.2       310.0
# 32         Dodge      Ram Pickup              19.460          5.2       230.0
# 33         Dodge       Ram Wagon              21.315          3.9       175.0
# 34         Dodge         Ram Van              18.575          3.9       175.0
# 35         Dodge          Dakota              16.980          2.5       120.0
# 42          Ford        Explorer              31.930          4.0       210.0
# 43          Ford        Windstar              21.410          3.0       150.0
# 44          Ford      Expedition              36.135          4.6       240.0
# 46          Ford        F-Series              26.935          4.6       220.0
# 50         Honda        Passport              26.600          3.2       205.0
# 58          Jeep  Grand Cherokee              26.895          4.0       195.0
# ...

# %% [markdown]
# Groupby

# %%
data.groupby(['Manufacturer'])['Price_in_thousands'].mean().reset_index()
# Out:
#    Manufacturer  Price_in_thousands
# 0         Acura           30.633333
# 1          Audi           39.980000
# 2           BMW           36.150000
# 3         Buick           26.781250
# 4      Cadillac           36.856667
# 5     Chevrolet           20.164375
# 6      Chrysler           22.280000
# 7         Dodge           24.170556
# 8          Ford           21.920500
# 9         Honda           20.277000
# 10      Hyundai           12.165667
# 11     Infiniti           29.465000
# 12         Jeep           20.991667
# 13        Lexus           41.105000
# 14      Lincoln           41.205000
# 15   Mercedes-B           58.487500
# 16      Mercury           20.748333
# 17   Mitsubishi           22.167429
# 18       Nissan           23.167200
# 19   Oldsmobile           27.829250
# 20     Plymouth           15.856667
# 21      Pontiac           22.412000
# 22      Porsche           62.473333
# 23       Saturn           12.503333
# 24       Toyota           21.934750
# ...

# %%
data.groupby(['Manufacturer','Model'])['Horsepower'].sum()
# Out:
# Manufacturer  Model
# Acura         Integra    140.0
#               RL         210.0
#               TL         225.0
# Audi          A4         150.0
#               A6         200.0
#                          ...
# Volkswagen    Cabrio     115.0
#               GTI        115.0
#               Golf       115.0
#               Jetta      115.0
#               Passat     150.0
# Name: Horsepower, Length: 117, dtype: float64

# %%
data.groupby(['Manufacturer','Model'])['Horsepower'].sum().reset_index()
# Out:
#     Manufacturer    Model  Horsepower
# 0          Acura  Integra       140.0
# 1          Acura       RL       210.0
# 2          Acura       TL       225.0
# 3           Audi       A4       150.0
# 4           Audi       A6       200.0
# ..           ...      ...         ...
# 112   Volkswagen   Cabrio       115.0
# 113   Volkswagen      GTI       115.0
# 114   Volkswagen     Golf       115.0
# 115   Volkswagen    Jetta       115.0
# 116   Volkswagen   Passat       150.0
#
# [117 rows x 3 columns]

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       RL               8.588               29.725
# 3           Audi       A4              20.397               22.255
# 4           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 112   Volkswagen     Golf               9.761               11.425
# 113   Volkswagen    Jetta              83.721               13.240
# 114   Volkswagen   Passat              51.102               16.725
# 115   Volkswagen   Cabrio               9.569               16.575
# 116   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data.query("Manufacturer=='Volkswagen'")
# Out:
#     Manufacturer   Model  Sales_in_thousands  __year_resale_value  \
# 112   Volkswagen    Golf               9.761               11.425
# 113   Volkswagen   Jetta              83.721               13.240
# 114   Volkswagen  Passat              51.102               16.725
# 115   Volkswagen  Cabrio               9.569               16.575
# 116   Volkswagen     GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 112    Passenger               14.90          2.0       115.0       98.9
# 113    Passenger               16.70          2.0       115.0       98.9
# 114    Passenger               21.20          1.8       150.0      106.4
# 115    Passenger               19.99          2.0       115.0       97.4
# 116    Passenger               17.50          2.0       115.0       98.9
#
#      Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
data.query("Horsepower < 200")
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 3           Audi       A4              20.397               22.255
# 6            BMW     328i               9.231               28.675
# 7            BMW     528i              17.527               36.125
# 8          Buick  Century              91.561               12.475
# ..           ...      ...                 ...                  ...
# 112   Volkswagen     Golf               9.761               11.425
# 113   Volkswagen    Jetta              83.721               13.240
# 114   Volkswagen   Passat              51.102               16.725
# 115   Volkswagen   Cabrio               9.569               16.575
# 116   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger              21.500          1.8       140.0      101.2
# ...

# %%
data.query("Manufacturer == 'Volkswagen' & Engine_size < 2.0 & Fuel_capacity >= 15")
# Out:
#     Manufacturer   Model  Sales_in_thousands  __year_resale_value  \
# 114   Volkswagen  Passat              51.102               16.725
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 114    Passenger                21.2          1.8       150.0      106.4
#
#      Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 114   184.1        3.043           16.4             27.0    10/30/2012
#
#      Power_perf_factor
# 114          61.701381

# %% [markdown]
# Pivot()

# %%
data.pivot_table(values = "Price_in_thousands", index = "Vehicle_type", columns = "Fuel_efficiency", aggfunc = 'sum')
# Out:
# Fuel_efficiency    15.0    16.0   17.0    18.0     19.0    20.0     21.0  \
# Vehicle_type
# Car              73.043  54.710  33.92  86.302  163.302  44.147   70.319
# Passenger           NaN  69.725    NaN     NaN      NaN  82.600  316.300
#
# Fuel_efficiency     22.0     23.0     24.0    25.0    26.0     27.0   28.0  \
# Vehicle_type
# Car               25.345   71.866   58.965     NaN     NaN   16.888    NaN
# Passenger        427.966  197.920  250.257  437.16  148.63  176.677  37.74
#
# Fuel_efficiency   29.0    30.0    31.0    32.0    33.0   45.0
# Vehicle_type
# Car                NaN     NaN     NaN     NaN     NaN    NaN
# Passenger        25.28  56.096  40.864  12.885  50.288  9.235

# %%
data.pivot_table(values = "Price_in_thousands", index = "Vehicle_type", columns = "Fuel_efficiency", aggfunc = 'sum', margins=True)
# Out:
# Fuel_efficiency    15.0     16.0   17.0    18.0     19.0     20.0     21.0  \
# Vehicle_type
# Car              73.043   54.710  33.92  86.302  163.302   44.147   70.319
# Passenger           NaN   69.725    NaN     NaN      NaN   82.600  316.300
# All              73.043  124.435  33.92  86.302  163.302  126.747  386.619
#
# Fuel_efficiency     22.0     23.0     24.0  ...    26.0     27.0   28.0  \
# Vehicle_type                                ...
# Car               25.345   71.866   58.965  ...     NaN   16.888    NaN
# Passenger        427.966  197.920  250.257  ...  148.63  176.677  37.74
# All              453.311  269.786  309.222  ...  148.63  193.565  37.74
#
# Fuel_efficiency   29.0    30.0    31.0    32.0    33.0   45.0       All
# Vehicle_type
# Car                NaN     NaN     NaN     NaN     NaN    NaN   698.807
# Passenger        25.28  56.096  40.864  12.885  50.288  9.235  2339.623
# All              25.28  56.096  40.864  12.885  50.288  9.235  3038.430
#
# ...
